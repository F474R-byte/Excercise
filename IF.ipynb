# %%
# Final Project A

# %%
## Introduction

# %%
## This notebook demonstrates basic Jupyter usage and simple data-science related examples required for the final project: lists, tables, arithmetic examples, code cells, and sharing instructions.

# %%
## Popular Data Science Languages
# Python
# R
# Julia
# SQL
# Scala

# %%
## Common Data Science Libraries (Python)
# NumPy
# pandas
# scikit-learn
# Matplotlib
# seaborn
# TensorFlow / PyTorch

# %%
# Exercise 8: multiply and add numbers
a = 7
b = 5
product = a * b
sum_result = a + b
product, sum_result
# Out:
# (35, 12)

# %%
# Exercise 9: convert minutes to hours
def minutes_to_hours(minutes):
    hours = minutes // 60
    remainder_minutes = minutes % 60
    return f"{minutes} minutes = {hours} hour(s) and {remainder_minutes} minute(s)"

# %%
## Objectives
1. Learn to create markdown and code cells in JupyterLite.
2. Demonstrate simple arithmetic and unit conversion with Python.
3. Show knowledge of common data-science tools, languages, and libraries.

# %%
**Author:** IF
